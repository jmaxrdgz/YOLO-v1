# %% [markdown]
# We first import the Pascal-VOC dataset (modified for YOLO) and store it in session's content folder.

# %%
import kagglehub
path = kagglehub.dataset_download("aladdinpersson/pascalvoc-yolo")
print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 4.31G/4.31G [03:41<00:00, 20.8MB/s]
# Extracting files...
# 100%|██████████| 4.31G/4.31G [03:41<00:00, 20.8MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/aladdinpersson/pascalvoc-yolo/versions/1
# Path to dataset files: /root/.cache/kagglehub/datasets/aladdinpersson/pascalvoc-yolo/versions/1

# %%
# !cp -r /root/.cache/kagglehub/datasets/aladdinpersson/pascalvoc-yolo/versions/1 /content/pascalvoc-yolo

# %% [markdown]
# The training parameters are defined in the train.py script.

# %%
# !python train.py
# Out:
# Train mAP: 0.0
# mean loss : 1178.3111877441406
# Train mAP: 0.0
# mean loss : 996.8722229003906
# Train mAP: 0.0
# mean loss : 748.4298299153646
# Train mAP: 3.57224530489475e-06
# mean loss : 487.2613118489583
# Train mAP: 0.0014942953130230308
# mean loss : 392.7654774983724
# Train mAP: 0.0
# mean loss : 374.48931884765625
# Train mAP: 0.0
# mean loss : 339.32081095377606
# Train mAP: 0.001490442780777812
# mean loss : 311.9449208577474
# Train mAP: 9.137424785876647e-05
# mean loss : 292.6702143351237
# Train mAP: 0.0029951028991490602
# mean loss : 258.4189860026042
# Train mAP: 2.249212411697954e-05
# mean loss : 254.85615030924478
# Train mAP: 0.0002579985302872956
# mean loss : 224.6825942993164
# Train mAP: 5.994050297886133e-05
# mean loss : 240.29463958740234
# Train mAP: 0.00019627227447926998
# mean loss : 240.1203867594401
# Train mAP: 0.00034329379559494555
# mean loss : 237.36849721272787
# Train mAP: 0.00031281160772778094
# mean loss : 223.85855865478516
# ...
